# %%
import mitsuba as mi
import matplotlib.pyplot as plt

mi.set_variant('scalar_rgb')
scene = mi.load_file("/home/screwdriver/samridha/mitsuba/scenes/cbox.xml")
# Render generates an tensor
image = mi.render(scene, spp=256)

# Use matplotlib to display the image
plt.axis("off")
plt.imshow(image ** (1.0 / 2.2)); # approximate sRGB tonemapping


# img = mi.render(mi.load_dict(mi.cornell_box()))
# # Use Bitmap as interface and write the data.
# mi.Bitmap(img)
# # Can write in exr or png format.
# mi.Bitmap(img).write('cbox.exr')
# mi.util.write_bitmap("my_first_render.png", image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..3.7914255].
